# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization
# Out:
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()

# %%
print('x_train shape' , x_train.shape)
print('y_train shape' , y_train.shape)
# Out:
# x_train shape (50000, 32, 32, 3)
# y_train shape (50000, 1)

# %%
plt.imshow(x_train[1])

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

# %%
datagen = ImageDataGenerator(
                            rotation_range = 15,
                            width_shift_range = 0.1,
                            height_shift_range=0.1,
                            horizontal_flip=True,
)

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0)

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10)
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
def results(model):
  epoch = 100
  r = model.fit(datagen.flow(x_train , y_train , batch_size = 32), epochs = epoch  ,steps_per_epoch=len(x_train)/32, validation_data = (x_val , y_val) , verbose = 1)
  acc = model.evaluate(x_test , y_test)
  print("test set loss : " , acc[0])
  print("test set accuracy :", acc[1]*100)

  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, r.history['accuracy'])
  plt.plot(epoch_range, r.history['val_accuracy'])
  plt.title('Classification Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range,r.history['loss'])
  plt.plot(epoch_range, r.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.show()

# %%
weight_decay = 1e-4
model = Sequential([
                    Conv2D(32, (3, 3), activation='relu', padding='same',kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
                    BatchNormalization(),
                    Conv2D(32, (3, 3), activation='relu',kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.2),
                    Conv2D(64, (3, 3), activation='relu',kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(64, (3, 3), activation='relu',kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),
                    Conv2D(128, (3, 3), activation='relu',kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(128, (3, 3), activation='relu',kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),
                    Flatten(),
                    Dense(128, activation='relu'),
                    Dense(10, activation='softmax')                    
])

opt =    tf.keras.optimizers.SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
results(model)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 1562/1562 [==============================] - 65s 41ms/step - loss: 1.7324 - accuracy: 0.3933 - val_loss: 1.5520 - val_accuracy: 0.4702
# Epoch 2/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 1.3777 - accuracy: 0.5348 - val_loss: 1.2056 - val_accuracy: 0.6172
# Epoch 3/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 1.1570 - accuracy: 0.6169 - val_loss: 1.1333 - val_accuracy: 0.6468
# Epoch 4/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 1.0097 - accuracy: 0.6715 - val_loss: 1.0311 - val_accuracy: 0.6830
# Epoch 5/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.9284 - accuracy: 0.7026 - val_loss: 0.9129 - val_accuracy: 0.7118
# Epoch 6/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.8768 - accuracy: 0.7185 - val_loss: 0.7353 - val_accuracy: 0.7750
# Epoch 7/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.8414 - accuracy: 0.7319 - val_loss: 0.8573 - val_accuracy: 0.7500
# Epoch 8/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.8111 - accuracy: 0.7453 - val_loss: 0.7357 - val_accuracy: 0.7778
# Epoch 9/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.7843 - accuracy: 0.7568 - val_loss: 0.7547 - val_accuracy: 0.7730
# Epoch 10/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.7636 - accuracy: 0.7650 - val_loss: 0.7005 - val_accuracy: 0.7922
# Epoch 11/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.7545 - accuracy: 0.7681 - val_loss: 0.7109 - val_accuracy: 0.8006
# Epoch 12/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.7388 - accuracy: 0.7763 - val_loss: 0.7324 - val_accuracy: 0.7846
# Epoch 13/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.7266 - accuracy: 0.7812 - val_loss: 0.6923 - val_accuracy: 0.8050
# Epoch 14/100
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.7130 - accuracy: 0.7882 - val_loss: 0.6760 - val_accuracy: 0.8084
# Epoch 15/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6997 - accuracy: 0.7915 - val_loss: 0.6978 - val_accuracy: 0.8054
# Epoch 16/100
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.6923 - accuracy: 0.7967 - val_loss: 0.6269 - val_accuracy: 0.8244
# Epoch 17/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.6880 - accuracy: 0.7983 - val_loss: 0.6908 - val_accuracy: 0.8110
# Epoch 18/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.6844 - accuracy: 0.8008 - val_loss: 0.6695 - val_accuracy: 0.8146
# Epoch 19/100
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.6755 - accuracy: 0.8037 - val_loss: 0.7035 - val_accuracy: 0.8090
# Epoch 20/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.6632 - accuracy: 0.8105 - val_loss: 0.6823 - val_accuracy: 0.8146
# Epoch 21/100
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.6626 - accuracy: 0.8095 - val_loss: 0.6394 - val_accuracy: 0.8268
# Epoch 22/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.6525 - accuracy: 0.8147 - val_loss: 0.6894 - val_accuracy: 0.8176
# Epoch 23/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.6531 - accuracy: 0.8155 - val_loss: 0.5960 - val_accuracy: 0.8434
# Epoch 24/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.6453 - accuracy: 0.8188 - val_loss: 0.7055 - val_accuracy: 0.8118
# Epoch 25/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6425 - accuracy: 0.8202 - val_loss: 0.6185 - val_accuracy: 0.8354
# Epoch 26/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6400 - accuracy: 0.8229 - val_loss: 0.6093 - val_accuracy: 0.8350
# Epoch 27/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6378 - accuracy: 0.8213 - val_loss: 0.6046 - val_accuracy: 0.8376
# Epoch 28/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6374 - accuracy: 0.8226 - val_loss: 0.6023 - val_accuracy: 0.8498
# Epoch 29/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6292 - accuracy: 0.8263 - val_loss: 0.6689 - val_accuracy: 0.8204
# Epoch 30/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.6218 - accuracy: 0.8294 - val_loss: 0.5972 - val_accuracy: 0.8500
# Epoch 31/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.6231 - accuracy: 0.8282 - val_loss: 0.6517 - val_accuracy: 0.8338
# Epoch 32/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6172 - accuracy: 0.8344 - val_loss: 0.5936 - val_accuracy: 0.8496
# Epoch 33/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6169 - accuracy: 0.8322 - val_loss: 0.5831 - val_accuracy: 0.8494
# Epoch 34/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6104 - accuracy: 0.8369 - val_loss: 0.6297 - val_accuracy: 0.8362
# Epoch 35/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6116 - accuracy: 0.8356 - val_loss: 0.6488 - val_accuracy: 0.8370
# Epoch 36/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6075 - accuracy: 0.8374 - val_loss: 0.6942 - val_accuracy: 0.8288
# Epoch 37/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6072 - accuracy: 0.8360 - val_loss: 0.6892 - val_accuracy: 0.8242
# Epoch 38/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6068 - accuracy: 0.8371 - val_loss: 0.6809 - val_accuracy: 0.8254
# Epoch 39/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6112 - accuracy: 0.8375 - val_loss: 0.6143 - val_accuracy: 0.8472
# Epoch 40/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6004 - accuracy: 0.8407 - val_loss: 0.5909 - val_accuracy: 0.8534
# Epoch 41/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6057 - accuracy: 0.8394 - val_loss: 0.5871 - val_accuracy: 0.8530
# Epoch 42/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6000 - accuracy: 0.8419 - val_loss: 0.5776 - val_accuracy: 0.8552
# Epoch 43/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5974 - accuracy: 0.8420 - val_loss: 0.5899 - val_accuracy: 0.8544
# Epoch 44/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5934 - accuracy: 0.8451 - val_loss: 0.5918 - val_accuracy: 0.8528
# Epoch 45/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5972 - accuracy: 0.8423 - val_loss: 0.5649 - val_accuracy: 0.8638
# Epoch 46/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5982 - accuracy: 0.8449 - val_loss: 0.5972 - val_accuracy: 0.8566
# Epoch 47/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5948 - accuracy: 0.8444 - val_loss: 0.6563 - val_accuracy: 0.8404
# Epoch 48/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5910 - accuracy: 0.8454 - val_loss: 0.6407 - val_accuracy: 0.8438
# Epoch 49/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5887 - accuracy: 0.8461 - val_loss: 0.7028 - val_accuracy: 0.8214
# Epoch 50/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5853 - accuracy: 0.8467 - val_loss: 0.5787 - val_accuracy: 0.8544
# Epoch 51/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5841 - accuracy: 0.8493 - val_loss: 0.5836 - val_accuracy: 0.8602
# Epoch 52/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5850 - accuracy: 0.8482 - val_loss: 0.5936 - val_accuracy: 0.8498
# Epoch 53/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5799 - accuracy: 0.8506 - val_loss: 0.6411 - val_accuracy: 0.8364
# Epoch 54/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5891 - accuracy: 0.8464 - val_loss: 0.5680 - val_accuracy: 0.8662
# Epoch 55/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5865 - accuracy: 0.8484 - val_loss: 0.6706 - val_accuracy: 0.8350
# Epoch 56/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5894 - accuracy: 0.8485 - val_loss: 0.5960 - val_accuracy: 0.8530
# Epoch 57/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5837 - accuracy: 0.8499 - val_loss: 0.6003 - val_accuracy: 0.8532
# Epoch 58/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5801 - accuracy: 0.8503 - val_loss: 0.6230 - val_accuracy: 0.8496
# Epoch 59/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5777 - accuracy: 0.8508 - val_loss: 0.6348 - val_accuracy: 0.8448
# Epoch 60/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5792 - accuracy: 0.8521 - val_loss: 0.6021 - val_accuracy: 0.8584
# Epoch 61/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5766 - accuracy: 0.8520 - val_loss: 0.5765 - val_accuracy: 0.8606
# Epoch 62/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5730 - accuracy: 0.8535 - val_loss: 0.6523 - val_accuracy: 0.8476
# Epoch 63/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5718 - accuracy: 0.8543 - val_loss: 0.6664 - val_accuracy: 0.8436
# Epoch 64/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5780 - accuracy: 0.8521 - val_loss: 0.5998 - val_accuracy: 0.8556
# Epoch 65/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5742 - accuracy: 0.8546 - val_loss: 0.6060 - val_accuracy: 0.8584
# Epoch 66/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5667 - accuracy: 0.8572 - val_loss: 0.6057 - val_accuracy: 0.8586
# Epoch 67/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5756 - accuracy: 0.8539 - val_loss: 0.6257 - val_accuracy: 0.8516
# Epoch 68/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5703 - accuracy: 0.8548 - val_loss: 0.5732 - val_accuracy: 0.8628
# Epoch 69/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5707 - accuracy: 0.8549 - val_loss: 0.6113 - val_accuracy: 0.8602
# Epoch 70/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5697 - accuracy: 0.8568 - val_loss: 0.6915 - val_accuracy: 0.8288
# Epoch 71/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5687 - accuracy: 0.8566 - val_loss: 0.6182 - val_accuracy: 0.8538
# Epoch 72/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5698 - accuracy: 0.8564 - val_loss: 0.5851 - val_accuracy: 0.8674
# Epoch 73/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5700 - accuracy: 0.8572 - val_loss: 0.5941 - val_accuracy: 0.8574
# Epoch 74/100
# 1562/1562 [==============================] - 63s 41ms/step - loss: 0.5714 - accuracy: 0.8569 - val_loss: 0.5677 - val_accuracy: 0.8662
# Epoch 75/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5614 - accuracy: 0.8596 - val_loss: 0.6648 - val_accuracy: 0.8440
# Epoch 76/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5694 - accuracy: 0.8557 - val_loss: 0.5908 - val_accuracy: 0.8614
# Epoch 77/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5657 - accuracy: 0.8577 - val_loss: 0.6493 - val_accuracy: 0.8404
# Epoch 78/100
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.5657 - accuracy: 0.8572 - val_loss: 0.5864 - val_accuracy: 0.8618
# Epoch 79/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5584 - accuracy: 0.8589 - val_loss: 0.5836 - val_accuracy: 0.8586
# Epoch 80/100
# 1562/1562 [==============================] - 67s 43ms/step - loss: 0.5686 - accuracy: 0.8585 - val_loss: 0.6076 - val_accuracy: 0.8566
# Epoch 81/100
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.5640 - accuracy: 0.8591 - val_loss: 0.7336 - val_accuracy: 0.8178
# Epoch 82/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5596 - accuracy: 0.8600 - val_loss: 0.6555 - val_accuracy: 0.8424
# Epoch 83/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5639 - accuracy: 0.8594 - val_loss: 0.6977 - val_accuracy: 0.8258
# Epoch 84/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5595 - accuracy: 0.8607 - val_loss: 0.6608 - val_accuracy: 0.8432
# Epoch 85/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5595 - accuracy: 0.8616 - val_loss: 0.5809 - val_accuracy: 0.8646
# Epoch 86/100
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.5612 - accuracy: 0.8602 - val_loss: 0.6047 - val_accuracy: 0.8564
# Epoch 87/100
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.5624 - accuracy: 0.8595 - val_loss: 0.5878 - val_accuracy: 0.8538
# Epoch 88/100
# 1562/1562 [==============================] - 70s 45ms/step - loss: 0.5562 - accuracy: 0.8615 - val_loss: 0.6384 - val_accuracy: 0.8456
# Epoch 89/100
# 1562/1562 [==============================] - 71s 46ms/step - loss: 0.5594 - accuracy: 0.8608 - val_loss: 0.6098 - val_accuracy: 0.8594
# Epoch 90/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5601 - accuracy: 0.8605 - val_loss: 0.5879 - val_accuracy: 0.8660
# Epoch 91/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5615 - accuracy: 0.8612 - val_loss: 0.5797 - val_accuracy: 0.8692
# Epoch 92/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5612 - accuracy: 0.8612 - val_loss: 0.5883 - val_accuracy: 0.8642
# Epoch 93/100
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5606 - accuracy: 0.8626 - val_loss: 0.5951 - val_accuracy: 0.8644
# Epoch 94/100
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5633 - accuracy: 0.8618 - val_loss: 0.5666 - val_accuracy: 0.8666
# Epoch 95/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5610 - accuracy: 0.8613 - val_loss: 0.5961 - val_accuracy: 0.8604
# Epoch 96/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5605 - accuracy: 0.8619 - val_loss: 0.6646 - val_accuracy: 0.8456
# Epoch 97/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5565 - accuracy: 0.8613 - val_loss: 0.6281 - val_accuracy: 0.8480
# Epoch 98/100
# 1562/1562 [==============================] - 63s 41ms/step - loss: 0.5546 - accuracy: 0.8646 - val_loss: 0.6160 - val_accuracy: 0.8584
# Epoch 99/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5541 - accuracy: 0.8630 - val_loss: 0.5819 - val_accuracy: 0.8680
# Epoch 100/100
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5529 - accuracy: 0.8648 - val_loss: 0.5854 - val_accuracy: 0.8658
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5858 - accuracy: 0.8594
# test set loss :  0.5857684016227722
# test set accuracy : 85.93999743461609

# %%
model.save("model1.hdf5")
# Out:
# C:\Users\Dawkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
